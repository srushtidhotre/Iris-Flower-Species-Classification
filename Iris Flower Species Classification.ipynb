# %%
import numpy as np                                                              #linear algebra
import pandas as pd                                                             # a data processing and CSV I/O library

# %%
import warnings                                                                 # current version of seaborn generates a bunch of warnings that will be ignore
warnings.filterwarnings('ignore')

# %%
import seaborn as sns                                                           # Data Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='white', color_codes=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-27352b01-31aa-4b4e-8725-ad6f19c13c35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27352b01-31aa-4b4e-8725-ad6f19c13c35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
iris = pd.read_csv("Iris Dataset for Task 1.csv")                               # load Iris Flower dataset
iris.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
iris['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm     Species
# count     150.000000    150.000000     150.000000    150.000000  150.000000
# mean        5.843333      3.057333       3.758000      1.199333    1.000000
# std         0.828066      0.435866       1.765298      0.762238    0.819232
# min         4.300000      2.000000       1.000000      0.100000    0.000000
# 25%         5.100000      2.800000       1.600000      0.300000    0.000000
# 50%         5.800000      3.000000       4.350000      1.300000    1.000000
# 75%         6.400000      3.300000       5.100000      1.800000    2.000000
# max         7.900000      4.400000       6.900000      2.500000    2.000000

# %%
iris.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.duplicated().sum()
# Out:
# 1

# %%
iris.shape
# Out:
# (150, 6)

# %%
l# Kdeplot creates and visualizes a kernel density estimate of the underlying feature

kdeplot = sns.FacetGrid(iris, hue="Species", height=6)
kdeplot.map(sns.kdeplot, "PetalLengthCm", fill=True)
kdeplot.add_legend()

plt.show()

# %%
# seaborn's FacetGrid is used to color the scatterplot by species

facetgrid = sns.FacetGrid(iris, hue="Species", height=6)
facetgrid.map(plt.scatter, "SepalLengthCm", "SepalWidthCm")
facetgrid.add_legend()

plt.show()

# %%
# Seaborn plot is the pairplot, which shows the bivariate relation between each pair of features
# Here, we observe that the Iris-setosa species is separataed from the other two across all feature combinations

sns.pairplot(iris, hue="Species", height=3)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

train, test = train_test_split(iris, test_size=0.3, random_state=42)            # Split the data into train (70%) and test (30%) sets

print("Training Dataset Shape:", train.shape)                                          # Print the shape of train and test sets
print("Testing Dataset Shape:", test.shape)
# Out:
# Training Dataset Shape: (105, 5)
# Testing Dataset Shape: (45, 5)

# %%
# Add target labels BEFORE splitting
iris['Species'] = iris_data.target

# Extract features (X) and target labels (y)

train_X = train[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]          # Features of train data
train_y = train['Species']                                                                   # Output labels of train data
test_X = test[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]            # Features of test data
test_y = test['Species']                                                                     # Output labels of test data

print("Train_X shape:", train_X.shape, "Train_y shape:", train_y.shape)                      # Print the shape of train and test sets
print("Test_X shape:", test_X.shape, "Test_y shape:", test_y.shape)
# Out:
# Train_X shape: (105, 4) Train_y shape: (105,)
# Test_X shape: (45, 4) Test_y shape: (45,)

# %%
train_X.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 81             5.5           2.4            3.7           1.0
# 133            6.3           2.8            5.1           1.5
# 137            6.4           3.1            5.5           1.8
# 75             6.6           3.0            4.4           1.4
# 109            7.2           3.6            6.1           2.5

# %%
test_X.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 73             6.1           2.8            4.7           1.2
# 18             5.7           3.8            1.7           0.3
# 118            7.7           2.6            6.9           2.3
# 78             6.0           2.9            4.5           1.5
# 76             6.8           2.8            4.8           1.4

# %%
train_y.head()
# Out:
# 81     1
# 133    2
# 137    2
# 75     1
# 109    2
# Name: Species, dtype: int64

# %%
model = KNeighborsClassifier(n_neighbors=3)                                      # this examines 3 neighbors for putting the data into class
model.fit(train_X, train_y)
prediction = model.predict(test_X)
print('The accuracy of K-Nearest Neighbour is: ', metrics.accuracy_score(prediction, test_y))
# Out:
# The accuracy of K-Nearest Neighbour is:  1.0

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_y, prediction)                                       # Compute the confusion matrix

plt.figure(figsize=(10, 6))                                                      # Plot the heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=iris_data.target_names, yticklabels=iris_data.target_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for KNN')

plt.show()
